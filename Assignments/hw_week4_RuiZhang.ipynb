# %%
import pandas as pd

# %%
df_m = pd.read_csv("m_data.csv")
df_f = pd.read_csv("w_data.csv")

# %%
df_m.head()
# Out:
#    Unnamed: 0    bmi  steps
# 0       22393   14.0  217.0
# 1       16685  171.0  176.0
# 2       15155   91.0  168.0
# 3        6162   86.0  101.0
# 4       22150  146.0  215.0

# %%
df_f.head()
# Out:
#    Unnamed: 0    bmi  steps
# 0       19914  179.0  200.0
# 1        1185  472.0   24.0
# 2       10394   29.0  135.0
# 3         138  499.0    7.0
# 4        8580   97.0  122.0

# %%
df_m['sex'] = 'm'

# %%
df_m[['steps', 'bmi']].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_f[['steps', 'bmi']].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_m['neg_bmi'] = - df_m['bmi']

# %%
df_m.plot.scatter(x = 'steps', y = 'neg_bmi', s = 0.5)
# Out:
# <AxesSubplot:xlabel='steps', ylabel='neg_bmi'>

# %%
df_f['neg_bmi'] = df_f['bmi'] * (-1)Wee

# %%
df_f.describe()
# Out:
#          Unnamed: 0           bmi         steps
# count  18548.000000  18548.000000  18548.000000
# mean   23282.573647    254.232909    220.864406
# std    13439.323095    174.901153    102.534039
# min        1.000000      0.000000      0.000000
# 25%    11537.250000     97.000000    144.000000
# 50%    23214.000000    200.000000    222.000000
# 75%    35035.750000    442.000000    296.000000
# max    46370.000000    549.000000    411.000000

# %%
df_f.plot.scatter(x = 'steps', y = 'neg_bmi', s = 0.5)
# Out:
# <AxesSubplot:xlabel='steps', ylabel='neg_bmi'>
